# %% [markdown]
# Essential utility commands

# %%
# %pylab notebook
import cv2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#cv2.TAB

# %%
#DIFFERENCE BETWEEN imshow is the matplotlib command and cv2.imshow is from open cv command both functions are same
#FOR HELP imshow press Shift and Tab or press imshow? shift enter

# %%
#CHECK PRESENT WORKING DIRECTORY
# !pwd
# Out:
# /home/wazir/ABC/CASIS-OpenCV-Course

# %%
ls
# Out:
# CASIS-OpenCV_Course_Session1.ipynb  data/
# CASIS-OpenCV_Course_Session2.ipynb  python/
# CASIS-OpenCV_Course_Session3.ipynb  README.md
# CASIS-OpenCV_Course_Session4.ipynb  zebra.bmp*

# %% [markdown]
# Reading and displaying image with numpy/matplot

# %%
# %cd (yourdirectory)
# %ls *.png
img = imread('zebra.bmp')
figure()
imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now the OpenCV way

# %%
import cv2
cvim2disp = cv2.imread('zebra.bmp')
cv2.imshow('THIS IS MY ZEBRA', cvim2disp)
cv2.waitKey(0) #image will not show until this is called
cv2.destroyAllWindows() #make sure window closes cleanly

# %% [markdown]
# Are numpy.imshow and cv2.imshow the same?

# %%
figure()
imshow(cvim2disp)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# What happened?? <br><br>
# For historical reasons, OpenCV defaults to USE BGR format instead of usual RGB <br><br>
# Solutions: <br><br>
# Use numpy/OpenCV consistently<br>
# or make sure to convert<br>

# %%
#SO CONVERT BGR TO RGB
cvimrgb = cv2.cvtColor(cvim2disp,cv2.COLOR_BGR2RGB) #FIRST IS IMAGE AND SECOND

#or
#imbgr = cv2.cvtColor(cvim2disp,cv2.COLOR_RGB2BGR)

figure()
imshow(cvimrgb)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Useful utility function

# %%
def mycvshow(imagein, title='NICE IMAGE TITEL'): #title can be specified or left to the default
    cv2.imshow(title,imagein)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

#we'll use this later, but for the most part we'll display inline
mycvshow(cvim2disp)

# %% [markdown]
# Simple filtering example
# Gaussian Filter

# %%
im2disp = imread('zebra.bmp')

blurred = cv2.GaussianBlur(im2disp,(19,19),0) #TAKE 19 BY 19 FILTER OF PIXEL, 0 MEANS SIGMA BASED ON SIZE

#OTHER METHOD more general method
kernel = np.ones((5,5),np.float32)/25 #create 5 by 5 kernel
blurred2 = cv2.filter2D(im2disp,-1,kernel)

figure()
imshow(blurred2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Saving an image

# %%
cv2.imwrite('wazirzebra.bmp', cvim2disp)
#or
#imsave('wazirzebra1.bmp',im2disp)
# Out:
# True

# %% [markdown]
# <head>
# <meta content="text/html; charset=ISO-8859-1"
# http-equiv="content-type">
# <title></title>
# </head>
# <body>
# <div style="text-align: center;">
# <a href="https://docs.scipy.org/doc/numpy-dev/user/numpy-for-matlab-users.html">Numpy
# for Matlab users</a> <br>
# </div>
# <style>
# table.docutils td { border: solid 1px #ccc; }
# </style>
# <div class="section" id="some-key-differences">
# <h2>Some Key Differences</h2>
# <table class="docutils" border="1">
# <colgroup>
# <col width="50%"><col width="50%">
# </colgroup><tbody valign="top">
# <tr class="row-odd">
# <td>In MATLAB®, the basic data type is a multidimensional array
# of
# double precision floating point numbers. Most expressions take such
# arrays and return such arrays. Operations on the 2-D instances of
# these arrays are designed to act more or less like matrix operations
# in linear algebra.</td>
# <td>In NumPy the basic type is a multidimensional <tt
# class="docutils literal"><span class="pre">array</span></tt>.
# Operations
# on these arrays in all dimensionalities including 2D are elementwise
# operations. However, there is a special <tt class="docutils literal"><span
# class="pre">matrix</span></tt> type for doing
# linear algebra, which is just a subclass of the <tt
# class="docutils literal"><span class="pre">array</span></tt> class.
# Operations on matrix-class arrays are linear algebra operations.</td>
# </tr>
# <tr class="row-even">
# <td>MATLAB® uses 1 (one) based indexing. The initial element of a
# sequence is found using a(1).
# <a class="reference internal" href="#numpy-for-matlab-users-notes"><em>See
# note INDEXING</em></a></td>
# <td>Python uses 0 (zero) based indexing. The initial element of a
# sequence is found using a[0].</td>
# </tr>
# <tr class="row-odd">
# <td>MATLAB®’s scripting language was created for doing linear
# algebra.
# The syntax for basic matrix operations is nice and clean, but the API
# for adding GUIs and making full-fledged applications is more or less
# an afterthought.</td>
# <td>NumPy is based on Python, which was designed from the outset
# to be
# an excellent general-purpose programming language. While Matlab’s
# syntax for some array manipulations is more compact than
# NumPy’s, NumPy (by virtue of being an add-on to Python) can do many
# things that Matlab just cannot, for instance subclassing the main
# array type to do both array and matrix math cleanly.</td>
# </tr>
# <tr class="row-even">
# <td>In MATLAB®, arrays have pass-by-value semantics, with a lazy
# copy-on-write scheme to prevent actually creating copies until they
# are actually needed. Slice operations copy parts of the array.</td>
# <td>In NumPy arrays have pass-by-reference semantics. Slice
# operations
# are views into an array.</td>
# </tr>
# </tbody>
# </table>
# </div>
# </body>

# %%
im2disp.dtype
# Out:
# dtype('uint8')

# %%
im2disp.shape #FISRT VALUE SHOW IMAGE HEIGHT , SECOND VALUE SHOW IMAGE WIDTH AND THIRD IS COLOR 
#CHANNEL 3 MEANS 1 CHANNEL PER IMAGE
# Out:
# (391, 586, 3)

# %%
whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# blurred     ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# blurred2    ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# cv2         module      <module 'cv2' from '/home<...>.5/site-packages/cv2.so'>
# cvim2disp   ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# cvimrgb     ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# im2disp     ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# imbgr       ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# img         ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# kernel      ndarray     5x5: 25 elems, type `float32`, 100 bytes
# mycvshow    function    <function mycvshow at 0x7fe98126e9d8>

# %%
#SHOWS TYPE AND DIMENSIONALITY
x=2
# %whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# blurred     ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# blurred2    ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# cv2         module      <module 'cv2' from '/home<...>.5/site-packages/cv2.so'>
# cvim2disp   ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# cvimrgb     ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# im2disp     ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# imbgr       ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# img         ndarray     391x586x3: 687378 elems, type `uint8`, 687378 bytes (671.267578125 kb)
# kernel      ndarray     5x5: 25 elems, type `float32`, 100 bytes
# mycvshow    function    <function mycvshow at 0x7fe98126e9d8>
# x           int         2

# %% [markdown]
# #1 numpy gotcha for people coming from Matlab
# #matlab counting from 1 to next, but in python counting from 0 to next

# %%
x = zeros(5)
y = x

y[1] - 1

#uncomment next line and run
print(x)
# Out:
# [0. 0. 0. 0. 0.]

# %% [markdown]
# What happened?  Why did modifying y change x?
# <br><br>A: Python copies arrays and other mutable data types by reference by default
# <br><br><br>Here's what you probably want:

# %%
x=zeros(5)
y=x.copy()

y[1] = 1

print(x)
# Out:
# [0. 0. 0. 0. 0.]

# %% [markdown]
# Let's run some of the included OpenCV examples

# %%
# %run inpaint.py
# Out:
# ERROR:root:File `'inpaint.py'` not found.

# %%
# %run deconvolution.py
# Out:
# ERROR:root:File `'deconvolution.py'` not found.

# %%
# %run find_obj.py
# Out:
# ERROR:root:File `'find_obj.py'` not found.

# %%
# %run peopledetect.py
# Out:
# ERROR:root:File `'peopledetect.py'` not found.
